# %% [markdown]
# # Revisión de datos, y uniones pertinentes para visualización

# %% [markdown]
# **Cargamos tablas para trabajar con ellas**

# %%
#importamos librerías
import pandas as pd

# %%
#cargarmos archivos
enero = pd.read_csv("../data/df_enero_game.csv")
febrero = pd.read_csv("../data/game_sales_feb.csv")
marzo = pd.read_csv("../data/games_sales_marzo.csv")
twich = pd.read_csv("../data/games_twich.csv")

# %% [markdown]
# **Vizualizamos y comenzamos a unir tablas**

# %%
#creamos una función para tener un paneo general de los df
def info_complete(df):
    info = df.info(memory_usage = "deep")
    print(info)
    shape = df.shape
    print(shape)
    describe = df.describe().T
    print(describe)
    print(df.head(3))
    print(df.tail(3))

# %%
info_complete(enero)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Posición     10 non-null     int64
#  1   Código PEGI  10 non-null     object
#  2   Juego        10 non-null     object
#  3   Plataforma   10 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 2.1 KB
# None
# (10, 4)
#           count  mean      std  min   25%  50%   75%   max
# Posición   10.0   5.5  3.02765  1.0  3.25  5.5  7.75  10.0
#    Posición Código PEGI                   Juego Plataforma
# 0         1         3 +                 FIFA 23        PS4
# 1         2         3 +                 FIFA 23     SWITCH
# 2         3         7 +  NINTENDO SWITCH SPORTS     SWITCH
#    Posición Código PEGI                          Juego Plataforma
# 7         8         7 +                 POKEMON VIOLET     SWITCH
# ...

# %%
info_complete(febrero)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   10 non-null     int64
#  1   Posición     10 non-null     int64
#  2   Código PEGI  10 non-null     object
#  3   Juego        10 non-null     object
#  4   Plataforma   10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 2.3 KB
# None
# (10, 5)
#             count  mean      std  min   25%  50%   75%   max
# Unnamed: 0   10.0   4.5  3.02765  0.0  2.25  4.5  6.75   9.0
# Posición     10.0   5.5  3.02765  1.0  3.25  5.5  7.75  10.0
#    Unnamed: 0  Posición Código PEGI            Juego Plataforma
# 0           0         1        16 +  HOGWARTS LEGACY        PS5
# 1           1         2         3 +          FIFA 23        PS4
# 2           2         3         3 +          FIFA 23     SWITCH
#    Unnamed: 0  Posición Código PEGI                 Juego Plataforma
# ...

# %%
info_complete(marzo)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Posición     10 non-null     int64
#  1   Código PEGI  10 non-null     object
#  2   Juego        10 non-null     object
#  3   Plataforma   10 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 2.2 KB
# None
# (10, 4)
#           count  mean      std  min   25%  50%   75%   max
# Posición   10.0   5.5  3.02765  1.0  3.25  5.5  7.75  10.0
#    Posición Código PEGI                     Juego Plataforma
# 0         1        18 +           RESIDENT EVIL 4        PS5
# 1         2        12 +  METROID PRIME REMASTERED     SWITCH
# 2         3        16 +           HOGWARTS LEGACY        PS5
#    Posición Código PEGI                                Juego Plataforma
# 7         8         7 +               NINTENDO SWITCH SPORTS     SWITCH
# ...

# %% [markdown]
# **Unificaremos las tres tablas de ventas en una que represente el primer trimestre**

# %%
first_q = pd.concat([enero, febrero, marzo], ignore_index=True)

# %%
first_q.head()
# Out:
#    Posición Código PEGI                           Juego Plataforma  Unnamed: 0
# 0         1         3 +                         FIFA 23        PS4         NaN
# 1         2         3 +                         FIFA 23     SWITCH         NaN
# 2         3         7 +          NINTENDO SWITCH SPORTS     SWITCH         NaN
# 3         4         3 +             MARIO KART 8 DELUXE     SWITCH         NaN
# 4         5         7 +  MARIO + RABBIDS SPARKS OF HOPE     SWITCH         NaN

# %%
info_complete(first_q)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Posición     30 non-null     int64
#  1   Código PEGI  30 non-null     object
#  2   Juego        30 non-null     object
#  3   Plataforma   30 non-null     object
#  4   Unnamed: 0   10 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 6.5 KB
# None
# (30, 5)
#             count  mean       std  min   25%  50%   75%   max
# Posición     30.0   5.5  2.921384  1.0  3.00  5.5  8.00  10.0
# Unnamed: 0   10.0   4.5  3.027650  0.0  2.25  4.5  6.75   9.0
#    Posición Código PEGI                   Juego Plataforma  Unnamed: 0
# 0         1         3 +                 FIFA 23        PS4         NaN
# 1         2         3 +                 FIFA 23     SWITCH         NaN
# 2         3         7 +  NINTENDO SWITCH SPORTS     SWITCH         NaN
# ...

# %%
first_q.value_counts("Unnamed: 0")
# Out:
# Unnamed: 0
# 0.0    1
# 1.0    1
# 2.0    1
# 3.0    1
# 4.0    1
# 5.0    1
# 6.0    1
# 7.0    1
# 8.0    1
# 9.0    1
# dtype: int64

# %%
#borraremos la columna de Unnamed: 0 porque no aporta nada
first_q.drop("Unnamed: 0", axis=1, inplace=True)

# %%
first_q.head(3)
# Out:
#    Posición Código PEGI                   Juego Plataforma
# 0         1         3 +                 FIFA 23        PS4
# 1         2         3 +                 FIFA 23     SWITCH
# 2         3         7 +  NINTENDO SWITCH SPORTS     SWITCH

# %% [markdown]
# **Continuamos con la de twich**

# %%
info_complete(twich)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    50 non-null     int64
#  1   Juego         50 non-null     object
#  2   Viewer Hours  50 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 7.2 KB
# None
# (50, 3)
#             count  mean       std  min    25%   50%    75%   max
# Unnamed: 0   50.0  24.5  14.57738  0.0  12.25  24.5  36.75  49.0
#    Unnamed: 0               Juego Viewer Hours
# 0           0       Just Chatting  236,892,841
# 1           1   League of Legends  103,696,990
# 2           2  Grand Theft Auto V  101,512,877
#     Unnamed: 0                  Juego Viewer Hours
# 47          47                  Retro    4,823,945
# 48          48  Talk Shows & Podcasts    4,693,597
# 49          49        Dark and Darker    4,576,232

# %%
#borraremos la columna de Unnamed: 0 porque no aporta nada
twich.drop("Unnamed: 0", axis=1, inplace=True)

# %%
#revisamos
twich.head()
# Out:
#                               Juego Viewer Hours
# 0                     Just Chatting  236,892,841
# 1                 League of Legends  103,696,990
# 2                Grand Theft Auto V  101,512,877
# 3                          VALORANT   93,217,700
# 4  Counter-Strike: Global Offensive   76,371,759

# %%
df_concat = pd.concat([enero, febrero, marzo])

# %%
df_concat.head(10)
# Out:
#    Posición Código PEGI                           Juego Plataforma    Mes  \
# 0         1         3 +                         FIFA 23        PS4  Enero
# 1         2         3 +                         FIFA 23     SWITCH  Enero
# 2         3         7 +          NINTENDO SWITCH SPORTS     SWITCH  Enero
# 3         4         3 +             MARIO KART 8 DELUXE     SWITCH  Enero
# 4         5         7 +  MARIO + RABBIDS SPARKS OF HOPE     SWITCH  Enero
# 5         6         3 +         JUST DANCE 2023 EDITION     SWITCH  Enero
# 6         7        12 +              FIRE EMBLEM ENGAGE     SWITCH  Enero
# 7         8         7 +                  POKEMON VIOLET     SWITCH  Enero
# 8         9         7 +                 POKEMON SCARLET     SWITCH  Enero
# 9        10         3 +   ANIMAL CROSSING: NEW HORIZONS     SWITCH  Enero
#
#    Unnamed: 0
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# ...

# %%
pivot_table.head(10)
# Out:
#          Código PEGI                                         Juego  \
# Mes            Enero Febrero Marzo                           Enero
# Posición
# 1                3 +    16 +  18 +                         FIFA 23
# 2                3 +     3 +  12 +                         FIFA 23
# 3                7 +     3 +  16 +          NINTENDO SWITCH SPORTS
# 4                3 +     7 +   3 +             MARIO KART 8 DELUXE
# 5                7 +    16 +  18 +  MARIO + RABBIDS SPARKS OF HOPE
# 6                3 +     7 +   3 +         JUST DANCE 2023 EDITION
# 7               12 +    18 +   3 +              FIRE EMBLEM ENGAGE
# 8                7 +     3 +   7 +                  POKEMON VIOLET
# 9                7 +    12 +   7 +                 POKEMON SCARLET
# 10               3 +    18 +   7 +   ANIMAL CROSSING: NEW HORIZONS
#
#                                                \
# Mes                                   Febrero
# Posición
# ...

# %%
pivot_table.to_excel("../data/pivot_table.xlsx")

# %%
twich.to_excel("../data/twich.xlsx")
first_q.to_excel("../data/first_q.xlsx")

# %%
enero.to_excel("../data/enero.xlsx")
febrero.to_excel("../data/febrero.xlsx")
marzo.to_excel("../data/marzo.xlsx")

# %%
febrero.to_csv("../data/febrero1.csv")

# %%
enero.head()
# Out:
#    Posición Código PEGI                           Juego Plataforma    Mes
# 0         1         3 +                         FIFA 23        PS4  Enero
# 1         2         3 +                         FIFA 23     SWITCH  Enero
# 2         3         7 +          NINTENDO SWITCH SPORTS     SWITCH  Enero
# 3         4         3 +             MARIO KART 8 DELUXE     SWITCH  Enero
# 4         5         7 +  MARIO + RABBIDS SPARKS OF HOPE     SWITCH  Enero

# %%
febrero.head()
# Out:
#    Posición Código PEGI                   Juego   Plataforma      Mes
# 0         1        16 +         HOGWARTS LEGACY          PS5  Febrero
# 1         2         3 +                 FIFA 23          PS4  Febrero
# 2         3         3 +                 FIFA 23       SWITCH  Febrero
# 3         4         7 +  NINTENDO SWITCH SPORTS       SWITCH  Febrero
# 4         5        16 +         HOGWARTS LEGACY  XBOX SERIES  Febrero

# %%
febrero.drop("Unnamed: 0",axis=1, inplace = True)

# %%
febrero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Posición     10 non-null     int64
#  1   Código PEGI  10 non-null     object
#  2   Juego        10 non-null     object
#  3   Plataforma   10 non-null     object
#  4   Mes          10 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 528.0+ bytes

# %%
marzo.head()
# Out:
#    Posición Código PEGI                     Juego Plataforma    Mes
# 0         1        18 +           RESIDENT EVIL 4        PS5  Marzo
# 1         2        12 +  METROID PRIME REMASTERED     SWITCH  Marzo
# 2         3        16 +           HOGWARTS LEGACY        PS5  Marzo
# 3         4         3 +       MARIO KART 8 DELUXE     SWITCH  Marzo
# 4         5        18 +           RESIDENT EVIL 4        PS4  Marzo

# %%
twich.head()
# Out:
#                               Juego Viewer Hours
# 0                     Just Chatting  236,892,841
# 1                 League of Legends  103,696,990
# 2                Grand Theft Auto V  101,512,877
# 3                          VALORANT   93,217,700
# 4  Counter-Strike: Global Offensive   76,371,759
